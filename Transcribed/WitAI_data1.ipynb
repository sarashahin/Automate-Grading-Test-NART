# %%
# !pip install wit
# Out:
# Collecting wit
#   Downloading wit-6.0.1.tar.gz (6.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: prompt_toolkit in /usr/local/lib/python3.10/dist-packages (from wit) (3.0.47)
# Requirement already satisfied: requests>=0.8.8 in /usr/local/lib/python3.10/dist-packages (from wit) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=0.8.8->wit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=0.8.8->wit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=0.8.8->wit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=0.8.8->wit) (2024.6.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt_toolkit->wit) (0.2.13)
# Building wheels for collected packages: wit
#   Building wheel for wit (setup.py) ... done
#   Created wheel for wit: filename=wit-6.0.1-py3-none-any.whl size=5296 sha256=2f63f194c2d961e7b3371921cb49ca379050a7229e5405cf0668d446d6851607
#   Stored in directory: /root/.cache/pip/wheels/a9/ea/7d/55ba15bb7612a6adea29f8085ad022e657c0ec8ba6ec6e7fc4
# Successfully built wit
# Installing collected packages: wit
# Successfully installed wit-6.0.1

# %%
import requests
import pandas as pd
import os
from tqdm import tqdm
import re

# Wit.ai Server Access Token
wit_ai_token = 'RFMDLLTIDEBNPNRLEPH2SF3FXMJQYRSF'

# Audio files directory
audio_dir = "/content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71"

#  transcribe audio using Wit.ai
def transcribe_audio_wit(file_path):
    headers = {
        'Authorization': f'Bearer {wit_ai_token}',
        'Content-Type': 'audio/wav',
    }
    with open(file_path, 'rb') as audio_file:
        response = requests.post('https://api.wit.ai/speech?v=20200513', headers=headers, data=audio_file)
    if response.status_code == 200:
        data = response.json()
        print(f"Response for {file_path}: {data}")  # Detailed logging
        if 'text' in data:
            text = data['text'].upper().strip()
            return text, 1.0  # use 1.0 as placeholder
    else:
        print(f"Error {response.status_code} for {file_path}: {response.text}")  # Error logging
    return "", 0.0

# Clean and normalize expected words
def clean_expected_word(word):
    # Remove any numeric prefix and spaces
    word = re.sub(r'^[\d_]+\s*', '', word)
    return word.upper().strip()

# Get all wav files
wav_files = [os.path.join(root, file) for root, _, files in os.walk(audio_dir) for file in files if file.endswith(".wav")]

# Process each wav file
results = []
for file_path in tqdm(wav_files, desc="Processing audio files"):
    detected_word, confidence = transcribe_audio_wit(file_path)
    expected_word = os.path.basename(os.path.dirname(file_path)).upper().strip()
    # Clean the expected word
    expected_word = clean_expected_word(expected_word)

    correct = 1 if detected_word == expected_word else 0

    results.append({
        "File": file_path,
        "Expected Word": expected_word,
        "Detected Word": detected_word,
        "Confidence": confidence,
        "Correct": correct
    })

# Convert results to a DataFrame
df = pd.DataFrame(results)

# Save results to CSV file
df.to_csv("transcription_results_wit.csv", index=False)

# Print DataFrame
print(df)

print("Transcription results saved to transcription_results_wit.csv")
# Out:
# Processing audio files:   0%|          | 1/3500 [00:02<2:32:03,  2.61s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP16.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7766, 'tokens': [{'end': 900, 'start': 0, 'token': 'Eight'}, {'end': 1260, 'start': 900, 'token': 'five.'}]}, 'text': 'Eight five', 'traits': {}}
# Processing audio files:   0%|          | 2/3500 [00:03<1:40:51,  1.73s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP51.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.3638, 'tokens': [{'end': 1140, 'start': 140, 'token': 'Beatify.'}]}, 'text': 'Beatify', 'traits': {}}
# Processing audio files:   0%|          | 3/3500 [00:04<1:19:07,  1.36s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP28.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4271, 'tokens': [{'end': 720, 'start': 0, 'token': 'Beatify.'}]}, 'text': 'Beatify', 'traits': {}}
# Processing audio files:   0%|          | 4/3500 [00:05<1:07:20,  1.16s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP52.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6785, 'tokens': [{'end': 780, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   0%|          | 5/3500 [00:06<1:05:19,  1.12s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP19.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.421, 'tokens': [{'end': 540, 'start': 0, 'token': 'Be'}, {'end': 840, 'start': 540, 'token': 'satisfied.'}]}, 'text': 'Be satisfied', 'traits': {}}
# Processing audio files:   0%|          | 6/3500 [00:07<59:26,  1.02s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP37.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7141, 'tokens': [{'end': 900, 'start': 0, 'token': 'Beatify.'}]}, 'text': 'Beatify', 'traits': {}}
# Processing audio files:   0%|          | 7/3500 [00:08<57:45,  1.01it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP4.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7903, 'tokens': [{'end': 720, 'start': 0, 'token': 'Beautiful.'}]}, 'text': 'Beautiful', 'traits': {}}
# Processing audio files:   0%|          | 8/3500 [00:09<1:03:39,  1.09s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP15.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6299, 'tokens': [{'end': 720, 'start': 0, 'token': 'Beat'}, {'end': 780, 'start': 720, 'token': 'a'}, {'end': 960, 'start': 780, 'token': 'fire'}]}, 'text': 'Beat a fire', 'traits': {}}
# Processing audio files:   0%|          | 9/3500 [00:10<1:02:47,  1.08s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP3.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6714, 'tokens': [{'end': 780, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   0%|          | 10/3500 [00:11<1:04:33,  1.11s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP20.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8074, 'tokens': [{'end': 1020, 'start': 20, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   0%|          | 11/3500 [00:12<1:04:45,  1.11s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP50.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.3885, 'tokens': [{'end': 1080, 'start': 80, 'token': 'Beatify'}]}, 'text': 'Beatify', 'traits': {}}
# Processing audio files:   0%|          | 12/3500 [00:13<1:03:20,  1.09s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP59.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7655, 'tokens': [{'end': 780, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   0%|          | 13/3500 [00:14<59:28,  1.02s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP39.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7044, 'tokens': [{'end': 1140, 'start': 140, 'token': 'Butterfly.'}]}, 'text': 'Butterfly', 'traits': {}}
# Processing audio files:   0%|          | 14/3500 [00:15<1:00:45,  1.05s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP22.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.2014, 'tokens': [{'end': 1140, 'start': 140, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   0%|          | 15/3500 [00:16<58:38,  1.01s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP38.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6155, 'tokens': [{'end': 720, 'start': 0, 'token': 'Spotify.'}]}, 'text': 'Spotify', 'traits': {}}
# Processing audio files:   0%|          | 16/3500 [00:17<56:11,  1.03it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP32.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.736, 'tokens': [{'end': 840, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   0%|          | 17/3500 [00:18<57:51,  1.00it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP24.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.634, 'tokens': [{'end': 540, 'start': 0, 'token': 'Beach'}, {'end': 780, 'start': 540, 'token': 'boy.'}]}, 'text': 'Beach boy', 'traits': {}}
# Processing audio files:   1%|          | 18/3500 [00:19<1:00:31,  1.04s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP47.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.621, 'tokens': [{'end': 540, 'start': 0, 'token': 'Be'}, {'end': 780, 'start': 540, 'token': 'autify.'}]}, 'text': 'Be autify', 'traits': {}}
# Processing audio files:   1%|          | 19/3500 [00:21<1:04:48,  1.12s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP34.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8403, 'tokens': [{'end': 900, 'start': 0, 'token': 'Be'}, {'end': 1080, 'start': 900, 'token': 'to'}, {'end': 1260, 'start': 1080, 'token': 'buy.'}]}, 'text': 'Be to buy', 'traits': {}}
# Processing audio files:   1%|          | 20/3500 [00:22<1:04:20,  1.11s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP54.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4371, 'tokens': [{'end': 900, 'start': 0, 'token': 'Beer'}, {'end': 960, 'start': 900, 'token': 'to'}, {'end': 1140, 'start': 960, 'token': 'fee.'}]}, 'text': 'Beer to fee', 'traits': {}}
# Processing audio files:   1%|          | 21/3500 [00:23<1:04:55,  1.12s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP44.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7627, 'tokens': [{'end': 900, 'start': 0, 'token': 'Be'}, {'end': 1260, 'start': 900, 'token': 'to'}, {'end': 1500, 'start': 1260, 'token': 'fight'}]}, 'text': 'Be to fight', 'traits': {}}
# Processing audio files:   1%|          | 22/3500 [00:24<1:01:34,  1.06s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP33.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8302, 'tokens': [{'end': 780, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   1%|          | 23/3500 [00:25<1:01:23,  1.06s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP58.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.9293, 'tokens': [{'end': 840, 'start': 0, 'token': 'Beautify'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   1%|          | 24/3500 [00:26<59:53,  1.03s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP25.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7939, 'tokens': [{'end': 900, 'start': 0, 'token': 'Beatify.'}]}, 'text': 'Beatify', 'traits': {}}
# Processing audio files:   1%|          | 25/3500 [00:27<1:07:00,  1.16s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP56.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8735, 'tokens': [{'end': 900, 'start': 0, 'token': 'Beatify.'}]}, 'text': 'Beatify', 'traits': {}}
# Processing audio files:   1%|          | 26/3500 [00:28<1:04:01,  1.11s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP43.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6953, 'tokens': [{'end': 720, 'start': 0, 'token': 'Petrify.'}]}, 'text': 'Petrify', 'traits': {}}
# Processing audio files:   1%|          | 27/3500 [00:30<1:04:32,  1.12s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP40.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8948, 'tokens': [{'end': 1080, 'start': 80, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   1%|          | 28/3500 [00:31<1:02:57,  1.09s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP41.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6129, 'tokens': [{'end': 720, 'start': 0, 'token': 'Beach'}, {'end': 960, 'start': 720, 'token': 'high.'}]}, 'text': 'Beach high', 'traits': {}}
# Processing audio files:   1%|          | 29/3500 [00:32<1:04:31,  1.12s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP49.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7371, 'tokens': [{'end': 960, 'start': 0, 'token': 'Beatify.'}]}, 'text': 'Beatify', 'traits': {}}
# Processing audio files:   1%|          | 30/3500 [00:33<1:02:16,  1.08s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP11.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4416, 'tokens': [{'end': 1140, 'start': 140, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   1%|          | 31/3500 [00:34<57:12,  1.01it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP13.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6959, 'tokens': [{'end': 660, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   1%|          | 32/3500 [00:34<52:38,  1.10it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP55.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7223, 'tokens': [{'end': 780, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   1%|          | 33/3500 [00:35<52:51,  1.09it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP48.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7378, 'tokens': [{'end': 960, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   1%|          | 34/3500 [00:36<59:07,  1.02s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP1.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.9014, 'tokens': [{'end': 900, 'start': 0, 'token': 'Eight'}, {'end': 960, 'start': 900, 'token': 'to'}, {'end': 1140, 'start': 960, 'token': 'five'}]}, 'text': 'Eight to five', 'traits': {}}
# Processing audio files:   1%|          | 35/3500 [00:38<1:03:26,  1.10s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP10.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.2893, 'tokens': [{'end': 1260, 'start': 260, 'token': 'Beatify.'}]}, 'text': 'Beatify', 'traits': {}}
# Processing audio files:   1%|          | 36/3500 [00:39<1:06:18,  1.15s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP46.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7538, 'tokens': [{'end': 1080, 'start': 80, 'token': 'B'}, {'end': 1140, 'start': 1080, 'token': 'to'}, {'end': 1440, 'start': 1140, 'token': 'five'}]}, 'text': 'B to five', 'traits': {}}
# Processing audio files:   1%|          | 37/3500 [00:40<1:04:31,  1.12s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP14.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.3045, 'tokens': [{'end': 840, 'start': 0, 'token': 'Beatify.'}]}, 'text': 'Beatify', 'traits': {}}
# Processing audio files:   1%|          | 38/3500 [00:41<1:03:14,  1.10s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP36.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4016, 'tokens': [{'end': 1080, 'start': 80, 'token': 'Beatify.'}]}, 'text': 'Beatify', 'traits': {}}
# Processing audio files:   1%|          | 39/3500 [00:42<1:02:09,  1.08s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP42.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.1861, 'tokens': [{'end': 1560, 'start': 560, 'token': 'Bettyfie.'}]}, 'text': 'Bettyfie', 'traits': {}}
# Processing audio files:   1%|          | 40/3500 [00:43<1:00:35,  1.05s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP17.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.771, 'tokens': [{'end': 1020, 'start': 20, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   1%|          | 41/3500 [00:44<58:33,  1.02s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP2.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6329, 'tokens': [{'end': 900, 'start': 0, 'token': 'Peach'}, {'end': 1260, 'start': 900, 'token': 'pie.'}]}, 'text': 'Peach pie', 'traits': {}}
# Processing audio files:   1%|          | 42/3500 [00:45<59:23,  1.03s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP45.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.9658, 'tokens': [{'end': 1020, 'start': 20, 'token': 'Beautify'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   1%|          | 43/3500 [00:46<1:00:41,  1.05s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP21.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7289, 'tokens': [{'end': 720, 'start': 0, 'token': 'Be'}, {'end': 1380, 'start': 720, 'token': 'defying'}]}, 'text': 'Be defying', 'traits': {}}
# Processing audio files:   1%|▏         | 44/3500 [00:47<58:20,  1.01s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP29.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6511, 'tokens': [{'end': 540, 'start': 0, 'token': 'Be'}, {'end': 600, 'start': 540, 'token': 'eight'}, {'end': 660, 'start': 600, 'token': 'to'}, {'end': 720, 'start': 660, 'token': 'five.'}]}, 'text': 'Be eight to five', 'traits': {}}
# Processing audio files:   1%|▏         | 45/3500 [00:48<57:02,  1.01it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP27.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.5296, 'tokens': [{'end': 960, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   1%|▏         | 46/3500 [00:49<58:04,  1.01s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP53.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8659, 'tokens': [{'end': 1140, 'start': 140, 'token': 'Beautify'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   1%|▏         | 47/3500 [00:50<56:59,  1.01it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP23.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.3708, 'tokens': [{'end': 420, 'start': 0, 'token': 'Beautiful'}]}, 'text': 'Beautiful', 'traits': {}}
# Processing audio files:   1%|▏         | 48/3500 [00:51<56:37,  1.02it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP35.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.9723, 'tokens': [{'end': 840, 'start': 0, 'token': 'Beatify.'}]}, 'text': 'Beatify', 'traits': {}}
# Processing audio files:   1%|▏         | 49/3500 [00:52<52:11,  1.10it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP12.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8286, 'tokens': [{'end': 840, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   1%|▏         | 50/3500 [00:53<52:40,  1.09it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP18.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.9282, 'tokens': [{'end': 540, 'start': 0, 'token': 'Beach'}, {'end': 900, 'start': 540, 'token': 'fry.'}]}, 'text': 'Beach fry', 'traits': {}}
# Processing audio files:   1%|▏         | 51/3500 [00:53<49:57,  1.15it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP5.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.5758, 'tokens': [{'end': 780, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   1%|▏         | 52/3500 [00:55<53:27,  1.07it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP26.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6239, 'tokens': [{'end': 720, 'start': 0, 'token': 'Be'}, {'end': 780, 'start': 720, 'token': 'to'}, {'end': 900, 'start': 780, 'token': 'fight'}]}, 'text': 'Be to fight', 'traits': {}}
# Processing audio files:   2%|▏         | 53/3500 [00:55<54:00,  1.06it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP30.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8658, 'tokens': [{'end': 1140, 'start': 140, 'token': 'Beautify'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   2%|▏         | 54/3500 [00:56<55:19,  1.04it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP57.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8055, 'tokens': [{'end': 540, 'start': 0, 'token': 'Be'}, {'end': 600, 'start': 540, 'token': 'able'}, {'end': 660, 'start': 600, 'token': 'to'}, {'end': 900, 'start': 660, 'token': 'fight'}]}, 'text': 'Be able to fight', 'traits': {}}
# Processing audio files:   2%|▏         | 55/3500 [00:58<58:00,  1.01s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP31.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6906, 'tokens': [{'end': 780, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   2%|▏         | 56/3500 [00:58<52:23,  1.10it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP65.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.9359, 'tokens': [{'end': 660, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   2%|▏         | 57/3500 [00:59<50:04,  1.15it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP6.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.9649, 'tokens': [{'end': 720, 'start': 0, 'token': 'Beautify'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   2%|▏         | 58/3500 [01:00<47:49,  1.20it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP62.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.438, 'tokens': [{'end': 720, 'start': 0, 'token': 'Beat'}, {'end': 780, 'start': 720, 'token': 'a'}, {'end': 960, 'start': 780, 'token': 'fly.'}]}, 'text': 'Beat a fly', 'traits': {}}
# Processing audio files:   2%|▏         | 59/3500 [01:01<52:44,  1.09it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP69.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.606, 'tokens': [{'end': 1080, 'start': 80, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   2%|▏         | 60/3500 [01:02<55:07,  1.04it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP68.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7375, 'tokens': [{'end': 780, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   2%|▏         | 61/3500 [01:03<54:47,  1.05it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP70.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7009, 'tokens': [{'end': 1020, 'start': 20, 'token': 'Beautifully'}, {'end': 1440, 'start': 1020, 'token': 'fry.'}]}, 'text': 'Beautifully fry', 'traits': {}}
# Processing audio files:   2%|▏         | 62/3500 [01:04<53:56,  1.06it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP64.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6803, 'tokens': [{'end': 720, 'start': 0, 'token': 'Be'}, {'end': 900, 'start': 720, 'token': 'to'}, {'end': 1080, 'start': 900, 'token': 'fire.'}]}, 'text': 'Be to fire', 'traits': {}}
# Processing audio files:   2%|▏         | 63/3500 [01:05<56:36,  1.01it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP7.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.782, 'tokens': [{'end': 900, 'start': 0, 'token': 'Beatify'}]}, 'text': 'Beatify', 'traits': {}}
# Processing audio files:   2%|▏         | 64/3500 [01:06<55:56,  1.02it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP61.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4336, 'tokens': [{'end': 1260, 'start': 260, 'token': 'Beatify.'}]}, 'text': 'Beatify', 'traits': {}}
# Processing audio files:   2%|▏         | 65/3500 [01:07<51:45,  1.11it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP60.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.5203, 'tokens': [{'end': 960, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   2%|▏         | 66/3500 [01:07<49:56,  1.15it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP66.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8238, 'tokens': [{'end': 1080, 'start': 80, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   2%|▏         | 67/3500 [01:08<52:40,  1.09it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP63.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8315, 'tokens': [{'end': 960, 'start': 0, 'token': 'Beautify.'}]}, 'text': 'Beautify', 'traits': {}}
# Processing audio files:   2%|▏         | 68/3500 [01:09<52:46,  1.08it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP71.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.5133, 'tokens': [{'end': 780, 'start': 0, 'token': 'BFI.'}]}, 'text': 'BFI', 'traits': {}}
# Processing audio files:   2%|▏         | 69/3500 [01:10<53:40,  1.07it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP9.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7018, 'tokens': [{'end': 900, 'start': 0, 'token': 'Beat'}, {'end': 1020, 'start': 900, 'token': 'a'}, {'end': 1140, 'start': 1020, 'token': 'fire.'}]}, 'text': 'Beat a fire', 'traits': {}}
# Processing audio files:   2%|▏         | 70/3500 [01:11<55:39,  1.03it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/44 BEATIFY/PP67.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.5814, 'tokens': [{'end': 960, 'start': 0, 'token': 'Beatify.'}]}, 'text': 'Beatify', 'traits': {}}
# Processing audio files:   2%|▏         | 71/3500 [01:12<56:01,  1.02it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP49.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6429, 'tokens': [{'end': 480, 'start': 0, 'token': 'Horde.'}]}, 'text': 'Horde', 'traits': {}}
# Processing audio files:   2%|▏         | 72/3500 [01:13<55:15,  1.03it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP22.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7101, 'tokens': [{'end': 900, 'start': 0, 'token': 'Code.'}]}, 'text': 'Code', 'traits': {}}
# Processing audio files:   2%|▏         | 73/3500 [01:14<55:08,  1.04it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP47.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7603, 'tokens': [{'end': 720, 'start': 0, 'token': 'Cord.'}]}, 'text': 'Cord', 'traits': {}}
# Processing audio files:   2%|▏         | 74/3500 [01:15<50:55,  1.12it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP61.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6803, 'tokens': [{'end': 540, 'start': 0, 'token': 'Chord.'}]}, 'text': 'Chord', 'traits': {}}
# Processing audio files:   2%|▏         | 75/3500 [01:16<52:03,  1.10it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP59.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4253, 'tokens': [{'end': 720, 'start': 0, 'token': 'Code.'}]}, 'text': 'Code', 'traits': {}}
# Processing audio files:   2%|▏         | 76/3500 [01:17<49:54,  1.14it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP63.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.5705, 'tokens': [{'end': 960, 'start': 0, 'token': 'Cord.'}]}, 'text': 'Cord', 'traits': {}}
# Processing audio files:   2%|▏         | 77/3500 [01:17<46:28,  1.23it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP15.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6091, 'tokens': [{'end': 420, 'start': 0, 'token': 'Chord.'}]}, 'text': 'Chord', 'traits': {}}
# Processing audio files:   2%|▏         | 78/3500 [01:18<44:21,  1.29it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP34.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6519, 'tokens': [{'end': 600, 'start': 0, 'token': 'Cord.'}]}, 'text': 'Cord', 'traits': {}}
# Processing audio files:   2%|▏         | 79/3500 [01:19<41:38,  1.37it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP43.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7105, 'tokens': [{'end': 420, 'start': 0, 'token': 'Code.'}]}, 'text': 'Code', 'traits': {}}
# Processing audio files:   2%|▏         | 80/3500 [01:20<46:47,  1.22it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP12.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6552, 'tokens': [{'end': 900, 'start': 0, 'token': 'Code.'}]}, 'text': 'Code', 'traits': {}}
# Processing audio files:   2%|▏         | 81/3500 [01:21<48:34,  1.17it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP52.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.9089, 'tokens': [{'end': 720, 'start': 0, 'token': 'Called.'}]}, 'text': 'Called', 'traits': {}}
# Processing audio files:   2%|▏         | 82/3500 [01:21<41:04,  1.39it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP65.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
# Processing audio files:   2%|▏         | 83/3500 [01:22<38:50,  1.47it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP38.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
# Processing audio files:   2%|▏         | 84/3500 [01:22<33:43,  1.69it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP71.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
# Processing audio files:   2%|▏         | 85/3500 [01:22<30:07,  1.89it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP68.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
# Processing audio files:   2%|▏         | 86/3500 [01:23<27:15,  2.09it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP24.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
# Processing audio files:   2%|▏         | 87/3500 [01:24<34:35,  1.64it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP53.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4295, 'tokens': [{'end': 1020, 'start': 20, 'token': 'Cord.'}]}, 'text': 'Cord', 'traits': {}}
# Processing audio files:   3%|▎         | 88/3500 [01:25<42:41,  1.33it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP2.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8605, 'tokens': [{'end': 780, 'start': 0, 'token': 'Called.'}]}, 'text': 'Called', 'traits': {}}
# Processing audio files:   3%|▎         | 89/3500 [01:26<46:10,  1.23it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP18.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4601, 'tokens': [{'end': 600, 'start': 0, 'token': 'Cord.'}]}, 'text': 'Cord', 'traits': {}}
# Processing audio files:   3%|▎         | 90/3500 [01:26<43:45,  1.30it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP29.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.5401, 'tokens': [{'end': 600, 'start': 0, 'token': 'Pulled.'}]}, 'text': 'Pulled', 'traits': {}}
# Processing audio files:   3%|▎         | 91/3500 [01:27<43:45,  1.30it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP27.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8339, 'tokens': [{'end': 720, 'start': 0, 'token': 'Court.'}]}, 'text': 'Court', 'traits': {}}
# Processing audio files:   3%|▎         | 92/3500 [01:28<36:11,  1.57it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP1.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
# Processing audio files:   3%|▎         | 93/3500 [01:28<32:42,  1.74it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP26.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
# Processing audio files:   3%|▎         | 94/3500 [01:29<38:57,  1.46it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP64.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8184, 'tokens': [{'end': 600, 'start': 0, 'token': 'Code.'}]}, 'text': 'Code', 'traits': {}}
# Processing audio files:   3%|▎         | 95/3500 [01:30<41:09,  1.38it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP36.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.9752, 'tokens': [{'end': 780, 'start': 0, 'token': 'Cold.'}]}, 'text': 'Cold', 'traits': {}}
# Processing audio files:   3%|▎         | 96/3500 [01:31<44:14,  1.28it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP10.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8409, 'tokens': [{'end': 720, 'start': 0, 'token': 'Court.'}]}, 'text': 'Court', 'traits': {}}
# Processing audio files:   3%|▎         | 97/3500 [01:31<41:30,  1.37it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP48.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.676, 'tokens': [{'end': 720, 'start': 0, 'token': 'Cord.'}]}, 'text': 'Cord', 'traits': {}}
# Processing audio files:   3%|▎         | 98/3500 [01:32<35:06,  1.61it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP56.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
# Processing audio files:   3%|▎         | 99/3500 [01:32<31:09,  1.82it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP28.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
# Processing audio files:   3%|▎         | 100/3500 [01:32<28:08,  2.01it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP51.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
# Processing audio files:   3%|▎         | 101/3500 [01:33<25:36,  2.21it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP69.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
# Processing audio files:   3%|▎         | 102/3500 [01:34<32:44,  1.73it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP4.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.5913, 'tokens': [{'end': 480, 'start': 0, 'token': 'Called.'}]}, 'text': 'Called', 'traits': {}}
# Processing audio files:   3%|▎         | 103/3500 [01:35<38:22,  1.48it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP66.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6138, 'tokens': [{'end': 840, 'start': 0, 'token': 'Poured.'}]}, 'text': 'Poured', 'traits': {}}
# Processing audio files:   3%|▎         | 104/3500 [01:36<44:59,  1.26it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP58.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7845, 'tokens': [{'end': 900, 'start': 0, 'token': 'Code.'}]}, 'text': 'Code', 'traits': {}}
# Processing audio files:   3%|▎         | 105/3500 [01:37<52:59,  1.07it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP11.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4788, 'tokens': [{'end': 900, 'start': 0, 'token': 'Cord.'}]}, 'text': 'Cord', 'traits': {}}
# Processing audio files:   3%|▎         | 106/3500 [01:38<50:47,  1.11it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP19.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.667, 'tokens': [{'end': 720, 'start': 0, 'token': 'Code.'}]}, 'text': 'Code', 'traits': {}}
# Processing audio files:   3%|▎         | 107/3500 [01:39<50:55,  1.11it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP23.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.5423, 'tokens': [{'end': 600, 'start': 0, 'token': 'Chord.'}]}, 'text': 'Chord', 'traits': {}}
# Processing audio files:   3%|▎         | 108/3500 [01:39<43:13,  1.31it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP40.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
# Processing audio files:   3%|▎         | 109/3500 [01:40<47:29,  1.19it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP42.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7048, 'tokens': [{'end': 540, 'start': 0, 'token': 'Chord.'}]}, 'text': 'Chord', 'traits': {}}
# Processing audio files:   3%|▎         | 110/3500 [01:41<44:25,  1.27it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP67.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6593, 'tokens': [{'end': 720, 'start': 0, 'token': 'Code.'}]}, 'text': 'Code', 'traits': {}}
# Processing audio files:   3%|▎         | 111/3500 [01:42<47:12,  1.20it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP25.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.3737, 'tokens': [{'end': 600, 'start': 0, 'token': 'Chord'}]}, 'text': 'Chord', 'traits': {}}
# Processing audio files:   3%|▎         | 112/3500 [01:43<47:19,  1.19it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP6.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6301, 'tokens': [{'end': 780, 'start': 0, 'token': 'Cord.'}]}, 'text': 'Cord', 'traits': {}}
# Processing audio files:   3%|▎         | 113/3500 [01:43<38:30,  1.47it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP32.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
# Processing audio files:   3%|▎         | 114/3500 [01:44<42:40,  1.32it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP45.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4911, 'tokens': [{'end': 840, 'start': 0, 'token': 'Cord.'}]}, 'text': 'Cord', 'traits': {}}
# Processing audio files:   3%|▎         | 115/3500 [01:45<43:50,  1.29it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP57.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.805, 'tokens': [{'end': 420, 'start': 0, 'token': 'Called.'}]}, 'text': 'Called', 'traits': {}}
# Processing audio files:   3%|▎         | 116/3500 [01:45<37:16,  1.51it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP3.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
# Processing audio files:   3%|▎         | 117/3500 [01:46<43:58,  1.28it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP16.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7373, 'tokens': [{'end': 900, 'start': 0, 'token': 'Called.'}]}, 'text': 'Called', 'traits': {}}
# Processing audio files:   3%|▎         | 118/3500 [01:47<48:37,  1.16it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP31.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.799, 'tokens': [{'end': 540, 'start': 0, 'token': 'Court'}]}, 'text': 'Court', 'traits': {}}
# Processing audio files:   3%|▎         | 119/3500 [01:48<46:06,  1.22it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP17.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8343, 'tokens': [{'end': 660, 'start': 0, 'token': 'Called.'}]}, 'text': 'Called', 'traits': {}}
# Processing audio files:   3%|▎         | 120/3500 [01:49<45:56,  1.23it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP7.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6419, 'tokens': [{'end': 360, 'start': 0, 'token': 'Chord'}]}, 'text': 'Chord', 'traits': {}}
# Processing audio files:   3%|▎         | 121/3500 [01:50<47:48,  1.18it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP44.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7309, 'tokens': [{'end': 720, 'start': 0, 'token': 'Call'}]}, 'text': 'Call', 'traits': {}}
# Processing audio files:   3%|▎         | 122/3500 [01:50<39:34,  1.42it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP9.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
# Processing audio files:   4%|▎         | 123/3500 [01:51<43:36,  1.29it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP21.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.5249, 'tokens': [{'end': 840, 'start': 0, 'token': 'Cord.'}]}, 'text': 'Cord', 'traits': {}}
# Processing audio files:   4%|▎         | 124/3500 [01:52<46:54,  1.20it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP70.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6467, 'tokens': [{'end': 600, 'start': 0, 'token': 'Cord'}]}, 'text': 'Cord', 'traits': {}}
# Processing audio files:   4%|▎         | 125/3500 [01:53<49:05,  1.15it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP60.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6072, 'tokens': [{'end': 720, 'start': 0, 'token': 'Cord.'}]}, 'text': 'Cord', 'traits': {}}
# Processing audio files:   4%|▎         | 126/3500 [01:54<49:09,  1.14it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP50.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4654, 'tokens': [{'end': 840, 'start': 0, 'token': 'Cord.'}]}, 'text': 'Cord', 'traits': {}}
# Processing audio files:   4%|▎         | 127/3500 [01:55<52:55,  1.06it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP37.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.789, 'tokens': [{'end': 960, 'start': 0, 'token': 'Called'}]}, 'text': 'Called', 'traits': {}}
# Processing audio files:   4%|▎         | 128/3500 [01:56<54:22,  1.03it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP41.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6128, 'tokens': [{'end': 900, 'start': 0, 'token': 'Cord.'}]}, 'text': 'Cord', 'traits': {}}
# Processing audio files:   4%|▎         | 129/3500 [01:57<52:07,  1.08it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP30.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6818, 'tokens': [{'end': 720, 'start': 0, 'token': 'Cord.'}]}, 'text': 'Cord', 'traits': {}}
# Processing audio files:   4%|▎         | 130/3500 [01:58<54:05,  1.04it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/01 CHORD/PP5.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4978, 'tokens': [{'end': 900, 'start': 0, 'token': 'Cord'}]}, 'text': 'Cord', 'traits': {}}
# ...
# Processing audio files:  99%|█████████▉| 3462/3500 [55:46<00:39,  1.03s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP4.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.3993, 'tokens': [{'end': 600, 'start': 0, 'token': 'Freelay'}]}, 'text': 'Freelay', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3463/3500 [55:47<00:39,  1.08s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP56.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6132, 'tokens': [{'end': 960, 'start': 0, 'token': 'Prolate.'}]}, 'text': 'Prolate', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3464/3500 [55:48<00:43,  1.22s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP24.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.5066, 'tokens': [{'end': 660, 'start': 0, 'token': 'Prelay.'}]}, 'text': 'Prelay', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3465/3500 [55:49<00:38,  1.10s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP34.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7453, 'tokens': [{'end': 780, 'start': 0, 'token': 'Polite.'}]}, 'text': 'Polite', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3466/3500 [55:50<00:34,  1.03s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP15.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.9549, 'tokens': [{'end': 600, 'start': 0, 'token': 'Pretty'}, {'end': 780, 'start': 600, 'token': 'late.'}]}, 'text': 'Pretty late', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3467/3500 [55:51<00:34,  1.05s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP63.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6887, 'tokens': [{'end': 1080, 'start': 80, 'token': 'Pretty'}, {'end': 1260, 'start': 1080, 'token': 'light'}]}, 'text': 'Pretty light', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3468/3500 [55:52<00:33,  1.06s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP44.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.9181, 'tokens': [{'end': 720, 'start': 0, 'token': 'Pre'}, {'end': 960, 'start': 720, 'token': 'late.'}]}, 'text': 'Pre late', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3469/3500 [55:53<00:30,  1.01it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP64.wav: {'entities': {}, 'intents': [], 'text': '', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3470/3500 [55:54<00:30,  1.00s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP35.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.3457, 'tokens': [{'end': 960, 'start': 0, 'token': 'Prelette.'}]}, 'text': 'Prelette', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3471/3500 [55:55<00:29,  1.03s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP70.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.2837, 'tokens': [{'end': 660, 'start': 0, 'token': 'Polite.'}]}, 'text': 'Polite', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3472/3500 [55:56<00:28,  1.01s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP13.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.5922, 'tokens': [{'end': 720, 'start': 0, 'token': 'Relate.'}]}, 'text': 'Relate', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3473/3500 [55:57<00:28,  1.04s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP42.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6788, 'tokens': [{'end': 780, 'start': 0, 'token': 'Prelate.'}]}, 'text': 'Prelate', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3474/3500 [55:58<00:26,  1.04s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP12.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4718, 'tokens': [{'end': 780, 'start': 0, 'token': 'Prelate.'}]}, 'text': 'Prelate', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3475/3500 [55:59<00:26,  1.04s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP32.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8958, 'tokens': [{'end': 780, 'start': 0, 'token': 'Prelate.'}]}, 'text': 'Prelate', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3476/3500 [56:00<00:23,  1.01it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP68.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.9341, 'tokens': [{'end': 600, 'start': 0, 'token': 'Pre'}, {'end': 720, 'start': 600, 'token': 'late.'}]}, 'text': 'Pre late', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3477/3500 [56:01<00:23,  1.03s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP27.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.9809, 'tokens': [{'end': 540, 'start': 0, 'token': 'Pre'}, {'end': 660, 'start': 540, 'token': 'late.'}]}, 'text': 'Pre late', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3478/3500 [56:02<00:20,  1.06it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP62.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.2484, 'tokens': [{'end': 660, 'start': 0, 'token': 'Pre-light'}]}, 'text': 'Pre-light', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3479/3500 [56:03<00:19,  1.10it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP2.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.5649, 'tokens': [{'end': 360, 'start': 0, 'token': 'Play'}]}, 'text': 'Play', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3480/3500 [56:04<00:18,  1.10it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP1.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8176, 'tokens': [{'end': 720, 'start': 0, 'token': 'Pretty'}, {'end': 1080, 'start': 720, 'token': 'late.'}]}, 'text': 'Pretty late', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3481/3500 [56:05<00:18,  1.04it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP23.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7145, 'tokens': [{'end': 660, 'start': 0, 'token': 'Prelate.'}]}, 'text': 'Prelate', 'traits': {}}
# Processing audio files:  99%|█████████▉| 3482/3500 [56:06<00:16,  1.08it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP61.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4378, 'tokens': [{'end': 960, 'start': 0, 'token': 'Prelate.'}]}, 'text': 'Prelate', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3483/3500 [56:07<00:15,  1.07it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP14.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.5477, 'tokens': [{'end': 540, 'start': 0, 'token': 'Play'}]}, 'text': 'Play', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3484/3500 [56:08<00:14,  1.10it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP60.wav: {'entities': {}, 'intents': [], 'text': '', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3485/3500 [56:08<00:13,  1.13it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP33.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.855, 'tokens': [{'end': 960, 'start': 0, 'token': 'Prelate'}]}, 'text': 'Prelate', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3486/3500 [56:09<00:12,  1.08it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP9.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.9346, 'tokens': [{'end': 780, 'start': 0, 'token': 'Pre'}, {'end': 960, 'start': 780, 'token': 'late.'}]}, 'text': 'Pre late', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3487/3500 [56:10<00:11,  1.10it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP6.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.3739, 'tokens': [{'end': 780, 'start': 0, 'token': 'Pre-light.'}]}, 'text': 'Pre-light', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3488/3500 [56:11<00:11,  1.03it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP71.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7244, 'tokens': [{'end': 1080, 'start': 80, 'token': 'Provide.'}]}, 'text': 'Provide', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3489/3500 [56:12<00:09,  1.12it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP57.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6324, 'tokens': [{'end': 600, 'start': 0, 'token': 'Clearly'}]}, 'text': 'Clearly', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3490/3500 [56:13<00:09,  1.07it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP41.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.3927, 'tokens': [{'end': 1020, 'start': 20, 'token': 'Prepaid.'}]}, 'text': 'Prepaid', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3491/3500 [56:14<00:08,  1.07it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP69.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.5414, 'tokens': [{'end': 720, 'start': 0, 'token': 'Prelate.'}]}, 'text': 'Prelate', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3492/3500 [56:15<00:06,  1.15it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP7.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.7436, 'tokens': [{'end': 420, 'start': 0, 'token': 'Relate.'}]}, 'text': 'Relate', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3493/3500 [56:16<00:06,  1.05it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP3.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6735, 'tokens': [{'end': 540, 'start': 0, 'token': 'Pre'}, {'end': 660, 'start': 540, 'token': 'late.'}]}, 'text': 'Pre late', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3494/3500 [56:17<00:05,  1.05it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP11.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4921, 'tokens': [{'end': 840, 'start': 0, 'token': 'Prelate.'}]}, 'text': 'Prelate', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3495/3500 [56:18<00:04,  1.05it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP26.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.8592, 'tokens': [{'end': 600, 'start': 0, 'token': 'Pre'}, {'end': 780, 'start': 600, 'token': 'late.'}]}, 'text': 'Pre late', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3496/3500 [56:19<00:03,  1.02it/s]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP51.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.4584, 'tokens': [{'end': 900, 'start': 0, 'token': 'Prelate.'}]}, 'text': 'Prelate', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3497/3500 [56:20<00:03,  1.02s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP40.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6553, 'tokens': [{'end': 780, 'start': 0, 'token': 'Pretty'}, {'end': 1080, 'start': 780, 'token': 'late.'}]}, 'text': 'Pretty late', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3498/3500 [56:21<00:02,  1.03s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP45.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.6182, 'tokens': [{'end': 840, 'start': 0, 'token': 'Prelate.'}]}, 'text': 'Prelate', 'traits': {}}
# Processing audio files: 100%|█████████▉| 3499/3500 [56:22<00:01,  1.09s/it]
# Response for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP67.wav: {'entities': {}, 'intents': [], 'speech': {'confidence': 0.9566, 'tokens': [{'end': 960, 'start': 0, 'token': 'Pretty'}, {'end': 1260, 'start': 960, 'token': 'late.'}]}, 'text': 'Pretty late', 'traits': {}}
# Processing audio files: 100%|██████████| 3500/3500 [56:23<00:00,  1.03it/s]
# Error 429 for /content/drive/MyDrive/audio_files/Dataset 1 (Cleaned with Separated Words)/NART Words Ss 1 to 71/45 PRELATE/PP48.wav: {
#   "code": "rate-limit",
#   "error": "You have exceeded the limit of 60 requests per minute for your app"
# }
#                                                    File Expected Word  \
# 0     /content/drive/MyDrive/audio_files/Dataset 1 (...       BEATIFY
# 1     /content/drive/MyDrive/audio_files/Dataset 1 (...       BEATIFY
# 2     /content/drive/MyDrive/audio_files/Dataset 1 (...       BEATIFY
# 3     /content/drive/MyDrive/audio_files/Dataset 1 (...       BEATIFY
# 4     /content/drive/MyDrive/audio_files/Dataset 1 (...       BEATIFY
# ...                                                 ...           ...
# 3495  /content/drive/MyDrive/audio_files/Dataset 1 (...       PRELATE
# 3496  /content/drive/MyDrive/audio_files/Dataset 1 (...       PRELATE
# 3497  /content/drive/MyDrive/audio_files/Dataset 1 (...       PRELATE
# 3498  /content/drive/MyDrive/audio_files/Dataset 1 (...       PRELATE
# 3499  /content/drive/MyDrive/audio_files/Dataset 1 (...       PRELATE
#
#      Detected Word  Confidence  Correct
# 0       EIGHT FIVE         1.0        0
# 1          BEATIFY         1.0        1
# 2          BEATIFY         1.0        1
# 3         BEAUTIFY         1.0        0
# 4     BE SATISFIED         1.0        0
# ...            ...         ...      ...
# 3495       PRELATE         1.0        1
# 3496   PRETTY LATE         1.0        0
# 3497       PRELATE         1.0        1
# 3498   PRETTY LATE         1.0        0
# 3499                       0.0        0
#
# [3500 rows x 5 columns]
# Transcription results saved to transcription_results_wit.csv
